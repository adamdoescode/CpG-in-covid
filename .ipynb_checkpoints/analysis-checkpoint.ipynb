# %% [markdown]
# # Analysis of frequencies of CpG bias in various organisms
#
# ## Inspired by:
#
# [Extreme Genomic CpG Deficiency in SARS-CoV-2 and Evasionof Host Antiviral Defense](https://academic.oup.com/mbe/advance-article/doi/10.1093/molbev/msaa094/5819559)
#
# [Compositional Biases of Bacterial Genomes and Evolutionary Implications](https://jb.asm.org/content/jb/179/12/3899.full.pdf)
#
# ## Introduction
#
# This is a simple project for learning how to do some bioinformatics, use git and github better and get a better understanding of biopython and the practicality of doing something like this in python.
#
# I conclude that I can probably find faster tools to do the same project in R or in Galaxy.

# %%
#imports
import Bio
from Bio import SeqIO
from Bio.Seq import Seq

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

#this script holds a set of useful functions I have built for this analysis
import cpg_functions

from random import choices
from collections import Counter

# %matplotlib inline

# %% [markdown]
# # Genomes used in this project
# These genomes are picked essentially arbitrarily. Some are from the papers. D. radiodurans is an extremophile that I find interesting. It handles very high levels of radiation.
# I did try to pick genomes that would be representative of different environmental niches. Of course the coronaviruses are all human pathogens of the lungs (and gut) while E. coli K12 is an attenuated strain recovered from a patient's stool. B. subtilis, and M. genitalium are similarly common pathogens but are not closely related to E. coli or each other. P. aerophilum is an archaea and so is genetically distant to all bacteria here.
# Keep in mind the viral genomes here are all of RNA viruses. The sequence here is the DNA equivalent of these, not the actual RNA sequence (which substitutes U for T). The original sequence seen by the sequencing machine would have been the cDNA template generated by reverse transcribing the RNA genome.
# ### Organisation of data
# The genomes are read into memory using the biopython `SeqIO` module. For *D. radiodurans* the file contains 4 records (2 chromosomes, 2 plasmids) which requires the use of `SeqIO.parse` while the rest are a single record in `fasta` or `genbank` files. These are loaded into a dictionary object so it is trivial to use in a loop while allowing for descriptive keys for each sequence record.

# %%
#d. radiodurans has 4 sequences: 2 chromosomes and 2 plasmids
#parse and convert to list 
D_rad_genomes = list(SeqIO.parse("sequences/deinococcus_radiodurans_ref.fna", "fasta"))

#easiest to refer to these in a dict:
genomes = {'covid-19': SeqIO.read("sequences/covid19ref.gb", "genbank"), 
           'betacoronavirus-1':SeqIO.read("sequences/betacorona1ref.gb", "genbank"),
           'corona-HKU1':SeqIO.read("sequences/coronaHKU1ref.gb", "genbank"),
           'corona-l63': SeqIO.read("sequences/coronanl63_ref.gb", "genbank"),
           'E. coli' : SeqIO.read("sequences/ecoli_k12_ref.fasta", "fasta"),
           'B. subtilis' : SeqIO.read("sequences/bsubtilis.fasta", "fasta"),
           'D. radiodurans chr1' : D_rad_genomes[0],
           'D. radiodurans chr2' : D_rad_genomes[1],
           'D. radiodurans plasmid 1' : D_rad_genomes[2],
           'D. radiodurans plasmid 2' : D_rad_genomes[3],
           'M. genitalium' : SeqIO.read("sequences/Mycoplasma_genitalium_ref.gbff", "genbank"),
           'P. aerophilum' : SeqIO.read("sequences/Pyrobaculum_aerophilum_ref.gbff", "genbank"),
           'HIV-1' : SeqIO.read('sequences/HIV1_ref.fna', "fasta"),
           'HIV-2' : SeqIO.read('sequences/HIV2_ref.fna', "fasta")
           }

# %% [markdown]
# # Nucleotide frequencies in each genome
# I am primarily interested in the single nucleotide and dinucleotide frequencies of each genome. The below cell will acquire these frequencies from each genome and produce two dictionaries with the same keys as the `genomes` dictionary. `singles` contains the single nucleotide frequencies and `doubles` contains the dinucleotide frequencies.

# %%
#get frequencies for each genome
genome_singles = {}
genome_doubles = {}
for key in genomes:
    genome_singles[key] = cpg_functions.windowed_base_count(sequence = genomes[key], k_window = 1)
    genome_doubles[key] = cpg_functions.windowed_base_count(sequence = genomes[key], k_window = 2)

def ratio_tables(singles, doubles):
    #get frequency of single bases as ratio of total bases
    genome_singles_ratio = {}
    for key in singles:
        total = sum(singles[key].values())
        temp_ratio_results = {}
        for base in ['A','T','C','G']:
            temp_ratio_results[base] = singles[key][base]/total
        genome_singles_ratio[key] = temp_ratio_results
        
    singles_table = pd.DataFrame(genome_singles_ratio)

    #do the same with double bases
    genome_doubles_ratio = {}
    for key in doubles:
        total = sum(doubles[key].values())
        temp_ratio_results = {}
        for base in doubles[key]:
            temp_ratio_results[base] = doubles[key][base]/total        
        genome_doubles_ratio[key] = temp_ratio_results
        
    doubles_table = pd.DataFrame(genome_doubles_ratio)
    return singles_table, doubles_table
singles_table, doubles_table = ratio_tables(genome_singles, genome_doubles)
#transpose for usefulness with pandas functions
singles_table = singles_table.T
doubles_table = doubles_table.T

# %% [markdown]
# # Single nucleotide frequencies in each genome
# Lets consider the single nucleotide frequencies first. The table below is of ratios of each single base compared to the total bases. The sum of each row is 1. We can see that frequencies vary a lot between different species here. The stronger colouring here is for larger numbers *in the row*, so for a given organism. We can see that A and T or C and G will have a darker tone and the others a lighter tone. It makes sense that A and T, or C and G, would be correlated since they bind each other in the typical double stranded DNA structure (this is not true for the single stranded +RNA coronaviruses).
#
# The four coronavirus genomes all have much higher levels of A and T compared to C and G. While *E. coli*, *P. aerophilum*, and *B. subtilis* have an almost neutral spreads of frequencies. *D radiodurans* skews heavily into C and G bases, except for plasmid 1 which has the same bias, but with less strength. *M. genitalium*, another human pathogen, has bias towards A and T bases similar to the coronaviruses.

# %%
#append AT ratio and CG ratio to table for reference here
singles_table.loc[:,'AT ratio'] = singles_table.apply(lambda x: x['A'] + x['T'], axis=1)
singles_table.loc[:,'CG ratio'] = singles_table.apply(lambda x: x['C'] + x['G'], axis=1)

#display a coloured table
cm = sns.light_palette("blue", as_cmap=True)
styled_singles = singles_table.style.background_gradient(cmap=cm, axis=1, subset=['A','T','C','G']) #only want single base freqs, not the summed ratios
styled_singles
# Out:
# <style  type="text/css" >
#     #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow0_col0 {
#             background-color:  #2323ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow0_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow0_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow0_col3 {
#             background-color:  #d1d1ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow1_col0 {
#             background-color:  #5959ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow1_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow1_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow1_col3 {
#             background-color:  #9d9dff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow2_col0 {
#             background-color:  #6767ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow2_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow2_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow2_col3 {
#             background-color:  #b3b3ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow3_col0 {
#             background-color:  #7878ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow3_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow3_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow3_col3 {
#             background-color:  #b2b2ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow4_col0 {
#             background-color:  #dedeff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow4_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow4_col2 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow4_col3 {
#             background-color:  #0f0fff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow5_col0 {
#             background-color:  #0404ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow5_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow5_col2 {
#             background-color:  #e3e3ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow5_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow6_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow6_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow6_col2 {
#             background-color:  #0101ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow6_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow7_col0 {
#             background-color:  #dcdcff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow7_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow7_col2 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow7_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow8_col0 {
#             background-color:  #dedeff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow8_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow8_col2 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow8_col3 {
#             background-color:  #0c0cff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow9_col0 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow9_col1 {
#             background-color:  #e2e2ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow9_col2 {
#             background-color:  #0202ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow9_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow10_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow10_col1 {
#             background-color:  #0a0aff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow10_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow10_col3 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow11_col0 {
#             background-color:  #b8b8ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow11_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow11_col2 {
#             background-color:  #4343ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow11_col3 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow12_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow12_col1 {
#             background-color:  #aeaeff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow12_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow12_col3 {
#             background-color:  #9494ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow13_col0 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow13_col1 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow13_col2 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_e7019fba_8f64_11ea_8d8e_7085c23622eerow13_col3 {
#             background-color:  #9797ff;
#             color:  #000000;
#         }</style><table id="T_e7019fba_8f64_11ea_8d8e_7085c23622ee" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >T</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >G</th>        <th class="col_heading level0 col4" >AT ratio</th>        <th class="col_heading level0 col5" >CG ratio</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id

# %% [markdown]
# # Dinucleotide frequencies in each genome
# It is more challenging to draw the same kind of observations from the dinucleotide table. But it is clear that there is considerable variation in nucleotide frequencies between organisms. I note that *D. radiodurans* plasmid 1 seems to really stick out from the other components of the genome! I wonder if the plasmid is only an occasional visitor in *D. radiodurans*' genomes? Plasmid 1's sequence must have been under different selective pressures at least sometime recently (in evolutionary time).

# %%
doubles_coloured = doubles_table.style.background_gradient(cmap=cm, axis=1)
display(doubles_coloured)
# Out:
# <style  type="text/css" >
#     #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col0 {
#             background-color:  #4b4bff;
#             color:  #f1f1f1;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col2 {
#             background-color:  #4545ff;
#             color:  #f1f1f1;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col3 {
#             background-color:  #1b1bff;
#             color:  #f1f1f1;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col4 {
#             background-color:  #7a7aff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col5 {
#             background-color:  #b0b0ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col6 {
#             background-color:  #6565ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col7 {
#             background-color:  #6262ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col8 {
#             background-color:  #c1c1ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col9 {
#             background-color:  #5e5eff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col10 {
#             background-color:  #9595ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col11 {
#             background-color:  #5e5eff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col13 {
#             background-color:  #8484ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col14 {
#             background-color:  #3333ff;
#             color:  #f1f1f1;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow0_col15 {
#             background-color:  #a9a9ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col0 {
#             background-color:  #4545ff;
#             color:  #f1f1f1;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col2 {
#             background-color:  #4a4aff;
#             color:  #f1f1f1;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col3 {
#             background-color:  #5f5fff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col4 {
#             background-color:  #8b8bff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col5 {
#             background-color:  #b0b0ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col6 {
#             background-color:  #6464ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col7 {
#             background-color:  #adadff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col8 {
#             background-color:  #d0d0ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col9 {
#             background-color:  #9090ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col10 {
#             background-color:  #b7b7ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col11 {
#             background-color:  #9b9bff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col13 {
#             background-color:  #9999ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col14 {
#             background-color:  #3838ff;
#             color:  #f1f1f1;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow1_col15 {
#             background-color:  #adadff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col0 {
#             background-color:  #5555ff;
#             color:  #f1f1f1;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col2 {
#             background-color:  #4e4eff;
#             color:  #f1f1f1;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col3 {
#             background-color:  #7373ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col4 {
#             background-color:  #a6a6ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col5 {
#             background-color:  #c4c4ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col6 {
#             background-color:  #7777ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col7 {
#             background-color:  #b8b8ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col8 {
#             background-color:  #d9d9ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col9 {
#             background-color:  #9a9aff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col10 {
#             background-color:  #b6b6ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col11 {
#             background-color:  #b9b9ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col12 {
#             background-color:  #e5e5ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col13 {
#             background-color:  #acacff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col14 {
#             background-color:  #6161ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow2_col15 {
#             background-color:  #cacaff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow3_col0 {
#             background-color:  #6e6eff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow3_col1 {
#             background-color:  #0000ff;
#             color:  #f1f1f1;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow3_col2 {
#             background-color:  #6767ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow3_col3 {
#             background-color:  #7777ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow3_col4 {
#             background-color:  #afafff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow3_col5 {
#             background-color:  #bebeff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow3_col6 {
#             background-color:  #6b6bff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow3_col7 {
#             background-color:  #aaaaff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow3_col8 {
#             background-color:  #d7d7ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow3_col9 {
#             background-color:  #9595ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow3_col10 {
#             background-color:  #b7b7ff;
#             color:  #000000;
#         }    #T_aeeab522_8f63_11ea_8d8e_7085c23622eerow3_col11 {
#             background-color:  #ababff;

# %% [markdown]
# # $I_{CpG}$ and $I*_{CpG}$ scores for each genome and the corresponding randomised genome
# We are interested in the frequency of CpG sequences in these genomes, that is a Cytosine (C) followed by a guanine (G). The 'p' stands for the phosphate that connects each sequence. The frequency of C and G's need to be considered as well if we want to consider the frequency of CpG sequences.
#
# The relative frequency of CpG sites compared to the proportion of the genome that is composed of Cs and Gs is called $I_{CpG}$. The formula is:
#
# $I_{CpG} = \frac{P_{CpG}}{P_{C}*P_{G}}$
#
# Where $P_{CpG}$ is the proportion of dinucleotides that are 'CG' and $P_{X}$ is the proportion of single nucleotides that are 'X'.
#
# Nucleotide sequences are typically represented in a 3' to 5' direction and when comparing between genomes we cannot be certain the genomes are facing "in the same direction" although this is relative. To counter this, we can use the symmetrized version of $I_{CpG}$ which is $I*_{CpG}$ and accounts for the reverse compliment using set theory and the understanding that base frequency of A in the normal orientation is equal to the T base frequency in reverse compliment.

# %%
#calculate Icpg values and produce a table

icpg_dict = {'organism':[],'Icpg':[],'I*cpg':[], 'CG':[]}

for key in genomes:
    #calculate ICpG valuesIt's
    Icpg = cpg_functions.calculate_icpg(genome_singles[key], genome_doubles[key])
    Icpg_sym = cpg_functions.symmetrized_Icpg(genome_singles[key], genome_doubles[key])
    cg = (genome_singles[key]['C']+genome_singles[key]['G'])/sum(genome_singles[key].values())

    icpg_dict['organism'].append(key)
    icpg_dict['Icpg'].append(Icpg)
    icpg_dict['I*cpg'].append(Icpg_sym)
    icpg_dict['CG'].append(cg)

icpg_table = pd.DataFrame(icpg_dict)

#this manually appends a kingdom designation for each organism which is useful for our graph below
kingdom = {'covid-19':'virus', 'betacoronavirus-1':'virus', 'corona-HKU1':'virus', 'corona-l63':'virus', 
               'E. coli':'bacteria', 'B. subtilis':'bacteria', 'D. radiodurans chr1':'bacteria', 'D. radiodurans chr2':'bacteria', 
               'D. radiodurans plasmid 1':'bacteria', 'D. radiodurans plasmid 2':'bacteria', 'M. genitalium':'bacteria', 
               'P. aerophilum':'archaea', 'HIV-1':'virus', 'HIV-2':'virus'}
icpg_table.loc[:,'kingdom'] = icpg_table['organism'].map(kingdom)

# %% [markdown]
# ## Table of $I_{CpG}$ and $I*_{CpG}$ scores
# It is clear that the symmetrized version differs only very slightly from $I_{CpG}$. This is partly because that C and G bases often have similar proportions in the genome so the reverse compliment does not change the frequencies by much.
#
# Colour coding the $I_{CpG}$ shows that the RNA viruses have lower scores than the bacterial genomes or the archaea, *P. aerophilum*.

# %%
cm_green = sns.light_palette("green", as_cmap=True)
icpg_table.style.background_gradient(cmap=cm_green, axis=0, subset=["Icpg","I*cpg","CG"])
# Out:
# <style  type="text/css" >
#     #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow0_col1 {
#             background-color:  #b5e4b5;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow0_col2 {
#             background-color:  #b4e4b4;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow0_col3 {
#             background-color:  #bde9bd;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow1_col1 {
#             background-color:  #a4dba4;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow1_col2 {
#             background-color:  #a6dca6;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow1_col3 {
#             background-color:  #c5edc5;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow2_col1 {
#             background-color:  #a9dea9;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow2_col2 {
#             background-color:  #acdfac;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow2_col3 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow3_col1 {
#             background-color:  #b3e3b3;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow3_col2 {
#             background-color:  #b5e4b5;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow3_col3 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow4_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow4_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow4_col3 {
#             background-color:  #69ba69;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow5_col1 {
#             background-color:  #1e901e;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow5_col2 {
#             background-color:  #1d901d;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow5_col3 {
#             background-color:  #99d599;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow6_col1 {
#             background-color:  #148b14;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow6_col2 {
#             background-color:  #148b14;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow6_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow7_col1 {
#             background-color:  #158b15;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow7_col2 {
#             background-color:  #158b15;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow7_col3 {
#             background-color:  #028102;
#             color:  #f1f1f1;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow8_col1 {
#             background-color:  #3ea23e;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow8_col2 {
#             background-color:  #3ea23e;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow8_col3 {
#             background-color:  #44a644;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow9_col1 {
#             background-color:  #239323;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow9_col2 {
#             background-color:  #239323;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow9_col3 {
#             background-color:  #1a8e1a;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow10_col1 {
#             background-color:  #bae7ba;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow10_col2 {
#             background-color:  #b9e7b9;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow10_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow11_col1 {
#             background-color:  #2c982c;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow11_col2 {
#             background-color:  #2c982c;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow11_col3 {
#             background-color:  #66b866;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow12_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow12_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow12_col3 {
#             background-color:  #a2daa2;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow13_col1 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow13_col2 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_aef04dac_8f63_11ea_8d8e_7085c23622eerow13_col3 {
#             background-color:  #8bcd8b;
#             color:  #000000;
#         }</style><table id="T_aef04dac_8f63_11ea_8d8e_7085c23622ee" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >organism</th>        <th class="col_heading level0 col1" >Icpg</th>        <th class="col_heading level0 col2" >I*cpg</th>        <th class="col_heading level0 col3" >CG</th>        <th class="col_heading level0 col4" >kingdom</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aef04dac_8f63_11ea_8d8e_7085c23622eelevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_aef04dac_8f63_11ea_8d8e_7085c23622eerow0_col0" class="data row0 col0" >covid-19</td>
#                         <td id="T_aef04dac_8f63_11ea_8d8e_7085c23622eerow0_col1" class="data row0 col1" >0.407703</td>
#                         <td id="T_aef04dac_8f63_11ea_8d8e_7085c23622eerow0_col2" class="data row0 col2" >0.407267</td>
#                         <td id="T_aef04dac_8f63_11ea_8d8e_7085c23622eerow0_col3" class="data row0 col3" >0.379728</td>
#                         <td id="T_aef04dac_8f63_11ea_8d8e_7085c23622eerow0_col4" class="data row0 col4" >virus</td>
#             </tr>
#             <tr>
#                         <th id="T_aef04dac_8f63_11ea_8d8e_7085c23622eelevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_aef04dac_8f63_11ea_8d8e_7085c23622eerow1_col0" class="data row1 col0" >betacoronavirus-1</td>
#                         <td id="T_aef04dac_8f63_11ea_8d8e_7085c23622eerow1_col1" class="data row1 col1" >0.481207</td>
#                         <td id="T_aef04dac_8f63_11ea_8d8e_7085c23622eerow1_col2" class="data row1 col2" >0.466322</td>
#                         <td id="T_aef04dac_8f63_11ea_8d8e_7085c23622eerow1_col3" class="data row1 col3" >0.367880</td>
#                         <td id="T_aef04dac_8f63_11ea_8d8e_7085c23622eerow1_col4" class="data row1 col4" >virus</td>
#             </tr>
#             <tr>
#                         <th id="T_aef04dac_8f63_11ea_8d8e_7085c23622eelevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_aef04dac_8f63_11ea_8d8e_7085c23622eerow2_col0" class="data row2 col0" >corona-HKU1</td>
#                         <td id="T_aef04dac_8f63_11ea_8d8e_7085c23622eerow2_col1" class="data row2 col1" >0.458391</td>
#                         <td id="T_aef04dac_8f63_11ea_8d8e_7085c2362

# %% [markdown]
# ## Graphing $I_{CpG}$ against %GC
# The graph below is of $I*_{CpG}$ compared to percentage GC content of each organism. On the left, colouring is by organism, while on the right, colouring is by kingdom. In this tiny subset of all sequenced organism there is a clear grouping of viruses (and pathogenic *M. genitalium*) into a low $I_{CpG}$/low %GC content group, while the remaining bacteria and archaea have relatively high $I_{CpG}$ values and quite high GC content. HIV-1 appears to have the lowest $I_{CpG}$ value, while *E. coli* has the highest.

# %%
#set useful defaults for matplotlib font to get easier to read figures
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 12}

matplotlib.rc('font', **font)

fig, (ax1, ax2) = plt.subplots(1,2, figsize = (20,7))

sns.scatterplot(x="CG", y="I*cpg", data=icpg_table, hue='organism', s=200, palette='tab20', ax=ax1)
sns.scatterplot(x="CG", y="I*cpg", data=icpg_table, hue='kingdom', s=200, palette='Set1', ax=ax2)

ax1.set_title('Coloured by organism')
ax2.set_title('Coloured by kingdom')

fig.suptitle('Density of CpG sites compared with percentage GC ')
# Out:
# Text(0.5, 0.98, 'Density of CpG sites compared with percentage GC ')
